# %%
import os
os.chdir("C:\\Users\\AfricaMultiple\\Documents\\wisskiDataImport")
os.getcwd()
# Out:
# 'C:\\Users\\AfricaMultiple\\Documents\\wisskiDataImport'

# %%
from api import Api, Pathbuilder, Entity
import pandas as pd

# %%
api_url = "***REMOVED***/wisski/api/v0"
auth = ()
headers = {"Cache-Control": "no-cache"}
api = Api(api_url, auth, headers)

# %%
api.pathbuilders = ['amo_ecrm__v01_dev_pb']

# %%
restype = pd.read_excel(r"C:\Users\AfricaMultiple\Documents\wisskiDataImport\roles.xlsx")
restype.head()
# Out:
#        roles
# 0   Abridger
# 1      Actor
# 2    Adapter
# 3  Addressee
# 4    Analyst

# %%
# for r in range(2,len(restype)):
#     tor = {"ffda4251282b4c206dc943c8988125f0" : [restype.iloc[r,0]]}
#     print(tor)
#     tor_entity = Entity(api=api, fields=tor, bundle_id = "bcca8ca49995c14a1b63968e77c54355")
#     api.save(tor_entity)
# Out:
# {'ffda4251282b4c206dc943c8988125f0': ['Adapter']}
# {'ffda4251282b4c206dc943c8988125f0': ['Addressee']}
# {'ffda4251282b4c206dc943c8988125f0': ['Analyst']}
# {'ffda4251282b4c206dc943c8988125f0': ['Animator']}
# {'ffda4251282b4c206dc943c8988125f0': ['Annotator']}
# {'ffda4251282b4c206dc943c8988125f0': ['Announcer']}
# {'ffda4251282b4c206dc943c8988125f0': ['Appellant']}
# {'ffda4251282b4c206dc943c8988125f0': ['Appellee']}
# {'ffda4251282b4c206dc943c8988125f0': ['Applicant']}
# {'ffda4251282b4c206dc943c8988125f0': ['Appraiser']}
# {'ffda4251282b4c206dc943c8988125f0': ['Architect']}
# {'ffda4251282b4c206dc943c8988125f0': ['Arranger']}
# {'ffda4251282b4c206dc943c8988125f0': ['Arranger of music']}
# {'ffda4251282b4c206dc943c8988125f0': ['Art copyist']}
# {'ffda4251282b4c206dc943c8988125f0': ['Art director']}
# {'ffda4251282b4c206dc943c8988125f0': ['Artist']}
# {'ffda4251282b4c206dc943c8988125f0': ['Artistic director']}
# {'ffda4251282b4c206dc943c8988125f0': ['Assignee']}
# ...
